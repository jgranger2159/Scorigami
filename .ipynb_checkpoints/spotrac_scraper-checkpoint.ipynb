# %%
from bs4 import BeautifulSoup as bs
import requests
import substring
import pandas as pd
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Define database and collection
db = client.nfl_teams
collection = db.nfl_teams

# %%
url = 'https://www.spotrac.com/nfl/cap/'

# %%
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html >
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js ie9 oldie" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <!-- start:global -->
#   <meta charset="utf-8"/>
#   <!-- end:global -->
#   <!-- start:page title -->
#   <title>
#    2018 NFL Team Salary Cap Space Tracker | Spotrac
#   </title>
#   <!-- end:page title -->
#   <!-- start:meta info -->
#   <meta content="2018,NFL, salary cap, space, team, rankings" name="keywords">
#    <meta content="A real-time look at the 2018 salary cap totals for each NFL team, including estimated cap space." name="description"/>
#    <meta content="NFL 2018 Salary Cap Tracker" property="og:title">
#     <meta content="Spotrac.com" property="og:site_name"/>
#     <meta content="https://www.spotrac.com/resources/images/og/og-nflcap.jpg" property="og:image"/>
#     <!-- end:meta info -->
#     <!-- start:responsive web design -->
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#     <!-- end:responsive web design -->
#     <!-- start:web fonts -->
#     <link href="//fonts.googleapis.com/css?family=Roboto:400,500,500italic,400italic,700,700italic%7CRoboto+Condensed:400,700%7CRoboto+Slab" rel="stylesheet" type="text/css"/>
#     <link href="//fonts.googleapis.com/css?family=Open+Sans:300,400,600,700" rel="stylesheet"/>
#     <!-- end:web fonts -->
#     <link href="https://www.spotrac.com/resources/css/bootstrap.min.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/css/font-awesome.min.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/css/jquery.sidr.dark.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/css/team.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/css/colors.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/css/option-colors.css" rel="stylesheet"/>
#     <link href="https://www.spotrac.com/resources/CreativeButtons/css/component.css" rel="stylesheet"/>
#     <link href="//www.spotrac.com/resources/css/responsive-tables.css" media="screen" rel="stylesheet" type="text/css">
#      <link href="https://www.spotrac.com/resources/css/style.css" rel="stylesheet"/>
#      <link href="https://www.spotrac.com/resources/css/premium.css" rel="stylesheet"/>
#      <script src="https://www.spotrac.com/resources/CreativeButtons/js/modernizr.custom.js">
#      </script>
#      <script async="" src="//ced.sascdn.com/tag/3265/smart.js" type="application/javascript">
#      </script>
#      <script type="application/javascript">
#       var sas = sas || {};
#     sas.cmd = sas.cmd || [];
#     sas.cmd.push(function() {
#         sas.setup({ networkid: 3265, domain: "//www15.smartadserver.com", async: true });
#     });
#     sas.cmd.push(function() {
#         sas.call("onecall", {
#             siteId: 272195,
#             pageId: 1017592,
#             formats: [
#                  { id: 71430 }
#                 ,{ id: 71427 }
#                 ,{ id: 71428 }
#             ],
#             target: ''
#         });
#     });
#      </script>
#      <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#      </script>
#      <script>
#       var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#      </script>
#      <script>
#       googletag.cmd.push(function() {
#     googletag.defineSlot('/1095629/spot1', [728, 90], 'div-gpt-ad-1542205012527-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#      </script>
#      <script>
#       googletag.cmd.push(function() {
#     googletag.defineSlot('/1095629/spot2', [300, 250], 'div-gpt-ad-1542723927026-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#      </script>
#      <script src="https://www.spotrac.com/resources/js/jquery.min.js">
#      </script>
#      <div class="optanon-alert-box-wrapper" style="bottom: 0px;">
#       <div class="optanon-alert-box-bottom-top">
#        <div class="optanon-alert-box-corner-close">
#         <a class="optanon-alert-box-close" href="#" onclick="Optanon.TriggerGoogleAnalyticsEvent('OneTrust Cookie Consent', 'Banner Close Button');" title="Close Banner">
#         </a>
#        </div>
#       </div>
#       <div class="optanon-alert-box-bg">
#        <div class="optanon-alert-box-button-container">
#         <div class="optanon-alert-box-button optanon-button-more">
#          <div class="optanon-alert-box-button-middle">
#           <a class="optanon-toggle-display cookie-alert-settings" href="#">
#            Cookie Settings
#           </a>
#          </div>
#         </div>
#         <div class="optanon-alert-box-button optanon-button-allow">
#          <div class="optanon-alert-box-button-middle">
#           <a class="optanon-allow-all cookie-alert-accept" href="#">
#            Accept Cookies
#           </a>
#          </div>
#         </div>
#         <div class="optanon-alert-box-button optanon-button-close">
#          <div class="optanon-alert-box-button-middle">
#           <a class="optanon-alert-box-close cookie-alert-close" href="#">
#            Close
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="optanon-clearfix optanon-alert-box-bottom-padding">
#        </div>
#        <div class="optanon-alert-box-logo">
#        </div>
#        <div class="optanon-alert-box-body">
#         <p>
#          We use cookies to offer you a better browsing experience, analyse site traffic, and serve targeted ads. Read how we use cookies and how you can control them in our “Cookie Settings”. By using our site, you consent to our use of cookies.
#         </p>
#        </div>
#        <div class="optanon-clearfix">
#        </div>
#       </div>
#      </div>
#      <!--[if lte IE 8]>
# 	<script src="https://www.spotrac.com/resources/js/respond.js"></script>
# 	<![endif]-->
#      <!--[if lt IE 9]>
# 	<link rel="stylesheet" href="https://www.spotrac.com/resources/css/photobox.ie.css">
# 	<script src="https://www.spotrac.com/resources/js/html5shiv.js"></script>
# 	<![endif]-->
#      <style>
#       .admin{ -webkit-column-rule: #A64;
# 	-moz-column-rule: #A64;
# 	-o-column-rule: #A64;
# 	column-rule: #A64;042 !important; }
# 	table.datatable td.average { background:#eee;color:#999;font-weight:bold;font-size:12px; padding:6px 22px !important;text-transform:uppercase;}
#      </style>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <script src="https://sac.ayads.co/sublime/9737" type="text/javascript">
#   </script>
#   <!-- start:page outer wrap -->
#   <div id="page-outer-wrap">
#    <!-- start:page inner wrap -->
#    <div id="page-inner-wrap">
#     <meta content="on" name="twitter:widgets:csp"/>
#     <!-- PREMIUM NAV -->
#     <!--MOBILE MENU-->
#     <header class="visible-xs" id="page-header-mobile">
#      <div class="row">
#       <!-- start:col -->
#       <div class="col-xs-8">
#        <!-- start:logo -->
#        <a href="https://www.spotrac.com/">
#         <img alt="Spotrac" class="mobile-logo" src="https://www.spotrac.com/resources/images/mark.png"/>
#         <h1>
#          spotrac
#         </h1>
#        </a>
#        <!-- end:logo -->
#       </div>
#       <div class="col-xs-4 text-right">
#        <a href="#" id="nav-expander" onclick="return false;">
#         <span class="fa fa-bars" style="z-index:1000000;position:relative;">
#         </span>
#        </a>
#       </div>
#       <!-- end:col -->
#      </div>
#      <!-- end:row -->
#      <!-- start:sidr -->
#      <div id="sidr">
#       <form action="https://www.spotrac.com/redirect/search/" id="search-form-mobile" method="post">
#        <input name="search" placeholder="Search a Player or Team" type="text"/>
#       </form>
#       <ul>
#        <li class="cat-nfl">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/nfl/">
#          NFL
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/nfl/cap/">
#            Team Salary Caps
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/positional/">
#            Positional Spending
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/contracts/">
#            Contracts
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/rankings/">
#            Salary Rankings
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/free-agents/">
#            Free Agents
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="#">
#            Trackers &amp; Tools
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/nfl/market-value/">
#              » Market Values
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/fines-suspensions/">
#              » Fines/Suspensions
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/injured-reserve/">
#              » IR Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/depth-charts/">
#              » Depth Charts Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/draft/">
#              » Draft Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/option/">
#              » Options
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nfl/college/">
#              » College Tracker
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/valuation/">
#            Best Values
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nfl/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-nba">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/nba/">
#          NBA
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/nba/cap/">
#            Team Cap Tracker
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/positional/">
#            Positional Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/contracts/">
#            Contracts
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/rankings/">
#            Salary Rankings
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/free-agents/">
#            Free Agents
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="https://www.spotrac.com/nba/free-agents/">
#            Trackers &amp; Tools
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/nba/depth-charts/">
#              » Depth Charts
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/option/">
#              » Options
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/fines-suspensions/">
#              » Fines/Suspensions
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/draft/">
#              » Draft Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/college/">
#              » College Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/transactions/trade/">
#              » Trade Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nba/country/">
#              » Country Tracker
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/valuation/">
#            Best Values
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nba/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-mlb">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/mlb/">
#          MLB
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/mlb/payroll/">
#            Team Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/positional/">
#            Positional Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/contracts/">
#            Contracts
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/rankings/">
#            Salary Rankings
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/free-agents/">
#            Free Agents
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="https://www.spotrac.com/mlb/free-agents/">
#            Trackers &amp; Tools
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/mlb/fines-suspensions/">
#              » Fines/Suspensions
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mlb/disabled-list/">
#              » Disabled List
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mlb/option/">
#              » Options Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mlb/transactions/trade/">
#              » Trade Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mlb/arbitration/">
#              » Arbitration Tracker
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/valuation/">
#            Best Values
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mlb/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-nhl">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/nhl/">
#          NHL
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/nhl/cap/">
#            Team Salary Caps
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/positional/">
#            Positional Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/contracts/">
#            Contracts
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/rankings/">
#            Salary Rankings
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/free-agents/">
#            Free Agents
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="https://www.spotrac.com/nhl/free-agents/">
#            Trackers &amp; Tools
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/nhl/injured-reserve/">
#              » IR Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/option/">
#              » Options
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/fines-suspensions/">
#              » Fines/Suspensions
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/draft/">
#              Draft Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/transactions/trade/">
#              » Trade Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/college/">
#              » College/Junior Team Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/nhl/country/">
#              » Country Tracker
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/valuation/">
#            Best Values
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/nhl/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-epl">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/epl/">
#          EPL
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/epl/">
#            Team Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/epl/positional/">
#            Positional Payrolls
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="#">
#            Salary Rankings
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/epl/rankings/">
#              » Average Salary
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/epl/rankings/weekly/">
#              » Weekly Wage
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/epl/rankings/contract-value/">
#              » Contract Value
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/epl/rankings/transfer-feee/">
#              » Transfer Feer
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/epl/transfers/">
#            Transfers
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/epl/free-agents/">
#            Free Agents
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/epl/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-mls">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="https://www.spotrac.com/mls/">
#          MLS
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/mls/">
#            Team Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mls/positional/">
#            Positional Payrolls
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mls/rankings/">
#            Salary Rankings
#           </a>
#          </li>
#          <li>
#           <a class="moremore" href="#">
#            <i class="fa fa-angle-down">
#            </i>
#           </a>
#           <a href="#">
#            Trackers &amp; Tools
#           </a>
#           <ul class="subsubnav">
#            <li>
#             <a href="https://www.spotrac.com/mls/cap/">
#              » Team Caps
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mls/draft/">
#              » Draft Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mls/college/">
#              » College Tracker
#             </a>
#            </li>
#            <li>
#             <a href="https://www.spotrac.com/mls/transactions/trade/">
#              » Trade Tracker
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/mls/transactions/">
#            Transactions
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-news">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a href="#">
#          More
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/radio/">
#            Radio Podcast
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/fantasy/">
#            Fantasy Contests
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/research/">
#            Research &amp; News
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-extra">
#         <a class="more" href="#">
#          <i class="fa fa-angle-down">
#          </i>
#         </a>
#         <a class="gold" href="#">
#          PREMIUM
#         </a>
#         <ul class="subnav-menu">
#          <li>
#           <a href="https://www.spotrac.com/signin/">
#            <i class="fa fa-sign-in">
#            </i>
#            Sign In
#           </a>
#          </li>
#          <li>
#           <a href="https://www.spotrac.com/register/">
#            <i class="fa fa-pencil-square-o">
#            </i>
#            Register
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="cat-news">
#         <a href="https://www.spotrac.com/contact/">
#          <i class="fa fa-envelope-o">
#          </i>
#          Contact Us
#         </a>
#        </li>
#        <li class="cat-news">
#         <a href="https://www.twitter.com/spotrac">
#          <i class="fa fa-twitter">
#          </i>
#          Twitter
#         </a>
#        </li>
#        <li class="cat-news">
#         <a href="https://www.facebook.com/spotrac">
#          <i class="fa fa-facebook">
#          </i>
#          Facebook
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- end:sidr -->
#      <!-- start:row -->
#     </header>
#     <!-- end:MOBILE MENU -->
#     <!---DESKTOP HEADER--->
#     <header class="hidden-xs" id="page-header">
#      <!-- start:header-branding -->
#      <div id="header-branding">
#       <!-- start:container -->
#       <div class="container xlarge">
#        <!-- start:row -->
#        <div class="row">
#         <!-- start:col -->
#         <div class="logo col-sm-3 col-md-3">
#          <!-- start:logo -->
#          <h1>
#           <a href="https://www.spotrac.com/">
#            <img alt="Sports Contracts, Salaries, &amp; Cap Hits" src="https://www.spotrac.com/resources/images/logo-300.png"/>
#           </a>
#          </h1>
#          <!-- end:logo -->
#         </div>
#         <!-- end:col -->
#         <!-- start:col -->
#         <div class="searchform col-sm-5 col-md-5 text-center col-sm-offset-1">
#          <form action="https://www.spotrac.com/redirect/search/" id="search-form" method="post">
#           <input name="search" placeholder="Search a Player or Team" type="text"/>
#           <button>
#            <span class="glyphicon glyphicon-search">
#            </span>
#           </button>
#          </form>
#         </div>
#         <!-- end:col -->
#         <!-- start:col -->
#         <div class=" social col-sm-3 col-lg-2 text-right">
#          <div class="weather">
#           <h4 style="display:block;">
#            Follow Spotrac
#           </h4>
#           <a href="https://www.spotrac.com/radio/">
#            <i class="fa fa-podcast fa-lg">
#            </i>
#           </a>
#           <a href="https://www.twitter.com/spotrac" target="_blank">
#            <i class="fa fa-twitter fa-lg">
#            </i>
#           </a>
#           <a href="https://www.facebook.com/spotrac" target="_blank">
#            <i class="fa fa-facebook-square fa-lg">
#            </i>
#           </a>
#          </div>
#         </div>
#         <!-- end:col -->
#        </div>
#        <!-- end:row -->
#       </div>
#       <!-- end:container -->
#      </div>
#      <!-- end:header-branding -->
#      <!-- start:header-navigation -->
#      <div id="header-navigation">
#       <!-- start:container -->
#       <div class="container xlarge">
#        <!-- start:menu -->
#        <nav id="menu">
#         <ul class="nav clearfix col-md-9">
#          <li class="home" style="height:40px;">
#           <a href="https://www.spotrac.com/">
#            <span class="glyphicon glyphicon-home">
#            </span>
#           </a>
#          </li>
#          <!---NFL--->
#          <li class="cat-nfl active">
#           <a class="clickable" href="#">
#            NFL
#            <i class="fa fa-caret-down">
#            </i>
#           </a>
#           <!-- start:submenu-NFL -->
#           <div class="subnav-container">
#            <ul class="subnav-menu">
#             <li class="current">
#              <a href="https://www.spotrac.com/nfl/cap/">
#               Team Salary Caps
#              </a>
#              <div class="subnav-posts">
#               <!-- start:NFL Teams -->
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/arizona-cardinals/cap/">
#                  Arizona Cardinals
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/atlanta-falcons/cap/">
#                  Atlanta Falcons
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/baltimore-ravens/cap/">
#                  Baltimore Ravens
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/buffalo-bills/cap/">
#                  Buffalo Bills
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/carolina-panthers/cap/">
#                  Carolina Panthers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/chicago-bears/cap/">
#                  Chicago Bears
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/cincinnati-bengals/cap/">
#                  Cincinnati Bengals
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/cleveland-browns/cap/">
#                  Cleveland Browns
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/dallas-cowboys/cap/">
#                  Dallas Cowboys
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/denver-broncos/cap/">
#                  Denver Broncos
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/detroit-lions/cap/">
#                  Detroit Lions
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/green-bay-packers/cap/">
#                  Green Bay Packers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/houston-texans/cap/">
#                  Houston Texans
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/indianapolis-colts/cap/">
#                  Indianapolis Colts
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/jacksonville-jaguars/cap/">
#                  Jacksonville Jaguars
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/kansas-city-chiefs/cap/">
#                  Kansas City Chiefs
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/los-angeles-chargers/cap/">
#                  Los Angeles Chargers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/los-angeles-rams/cap/">
#                  Los Angeles Rams
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/miami-dolphins/cap/">
#                  Miami Dolphins
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/minnesota-vikings/cap/">
#                  Minnesota Vikings
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/new-england-patriots/cap/">
#                  New England Patriots
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/new-orleans-saints/cap/">
#                  New Orleans Saints
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/new-york-giants/cap/">
#                  New York Giants
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/new-york-jets/cap/">
#                  New York Jets
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/oakland-raiders/cap/">
#                  Oakland Raiders
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/philadelphia-eagles/cap/">
#                  Philadelphia Eagles
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/pittsburgh-steelers/cap/">
#                  Pittsburgh Steelers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/san-francisco-49ers/cap/">
#                  San Francisco 49ers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/seattle-seahawks/cap/">
#                  Seattle Seahawks
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tampa-bay-buccaneers/cap/">
#                  Tampa Bay Buccaneers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tennessee-titans/cap/">
#                  Tennessee Titans
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/washington-redskins/cap/">
#                  Washington Redskins
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#               </ul>
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/positional/">
#               Positional Payrolls
#              </a>
#              <div class="subnav-posts">
#               <!-- start:NFL positions -->
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/offense/">
#                  Offense
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/quarterback/">
#                  Quarterback
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/running-back/">
#                  Running Back
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/fullback/">
#                  Fullback
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/wide-receiver/">
#                  Wide Receiver
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/tight-end/">
#                  Tight End
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/offensive-line/">
#                  Offensive Line
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/tackle/">
#                  Tackle
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/left-tackle/">
#                  Left Tackle
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/right-tackle/">
#                  Right Tackle
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/guard/">
#                  Guard
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/center/">
#                  Center
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/defense/">
#                  Defense
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/defensive-line/">
#                  Defensive Line
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/defensive-end/">
#                  Defensive End
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/defensive-tackle/">
#                  Defensive Tackle
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/linebacker/">
#                  Linebacker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/outside-linebacker/">
#                  Outside Linebacker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/inside-linebacker/">
#                  Inside Linebacker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/edge/">
#                  Edge
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/secondary/">
#                  Secondary
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/cornerback/">
#                  Cornerback
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/safety/">
#                  Safety
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/free-safety/">
#                  Free Safety
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/strong-safety/">
#                  Strong Safety
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/special/">
#                  Special Teams
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/kicker/">
#                  Kicker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/punter/">
#                  Punter
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/positional/long-snapper/">
#                  Long Snapper
#                 </a>
#                </li>
#               </ul>
#               <!-- end:NFL positions -->
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/contracts/">
#               Contracts
#              </a>
#              <div class="subnav-posts">
#               <!-- start:NFL Contracts -->
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/">
#                  Contracts By Team
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/quarterback/">
#                  Contracts By Position
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/sort-value/">
#                  Largest Contracts
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/sort-length/">
#                  Longest Contracts
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/injured-reserve/">
#                  Contracts on IR
#                 </a>
#                 <li>
#                  <a href="https://www.spotrac.com/nfl/free-agents/">
#                   Expiring Contracts
#                  </a>
#                 </li>
#                </li>
#               </ul>
#               <ul class="menu-list" style="width:40%;">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/cumulative-cash/">
#                  Cumulative Cash per Contract
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/quarterback/">
#                  Contract Breakdowns by Years
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/type-rookie/">
#                  Rookie Contracts
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/type-veteran/">
#                  Veteran Contracts
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/college/">
#                  Contracts by College
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/sort-age/">
#                  Contracts by Age
#                 </a>
#                </li>
#               </ul>
#               <!-- end:nfl contracts -->
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/rankings/">
#               Salary Rankings
#              </a>
#              <div class="subnav-posts">
#               <!-- start:NFL Rankings -->
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/">
#                  Top Cap Hits
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/base/">
#                  Top Base Salaries
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/average/">
#                  Average Salaries
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/cash/">
#                  Top Annual Cash
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/guaranteed/">
#                  Top Guaranteed Money
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/signing-bonus/">
#                  Top Signing Bonuses
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/dead-money/">
#                  Top Dead Cap
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/earnings/">
#                  Career Earnings
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/base/arizona-cardinals/">
#                  Salaries by Team
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/base/quarterback/">
#                  Salaries by Position
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/arizona-cardinals/">
#                  Cap Hits by Team
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/quarterback/">
#                  Cap Hits by Position
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/rankings/franchise-tag/">
#                  Franchise Tags
#                 </a>
#                </li>
#               </ul>
#               <!-- end:NFL rankings -->
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/trackers/">
#               Trackers &amp; Tools
#              </a>
#              <div class="subnav-posts">
#               <ul class="menu-list" style="width:21%;">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/cap/">
#                  Team Salary Cap Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/free-agents/">
#                  Free Agent Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/fines-suspensions/">
#                  Fines &amp; Suspensions
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/injured-reserve/">
#                  Injured Reserve
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/transactions/trade/">
#                  Trade Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/draft/">
#                  Draft Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/option/">
#                  Option Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/college/">
#                  College Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/agents/">
#                  Agents Tracker
#                 </a>
#                </li>
#               </ul>
#               <ul class="menu-list" style="width:25%;">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/market-value/">
#                  Current Market Values
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/depth-charts/">
#                  Depth Charts Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tools/visual-roster-spending/">
#                  Visual Roster Spending
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tools/offseason/">
#                  Offseason Spending
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tools/contract-builder/">
#                  Contract Builder
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/tools/roster/">
#                  Roster/Salary Cap Manager
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/valuation/">
#               Best Values
#              </a>
#              <div class="subnav-posts">
#               <ul class="menu-list" style="width:50%;">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/valuation/">
#                  Best Value Players
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/valuation/offense/">
#                  Best Value Offensive Players
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/valuation/defense/">
#                  Best Value Defensive Players
#                 </a>
#                </li>
#                <li>
#                 <a href="#">
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/valuation/team/">
#                  Best Value Teams
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/statistics/">
#               Statistics
#              </a>
#              <div class="subnav-posts">
#               <ul class="menu-list" style="width:300px">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/statistics/">
#                  Statistics Leaders
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/statistics/player/">
#                  Player Statistics
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/statistics/team/">
#                  Team Statistics
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li>
#              <a href="https://www.spotrac.com/nfl/transactions/">
#               Transactions
#              </a>
#              <div class="subnav-posts">
#               <ul class="menu-list" style="width:50%;">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/transactions/">
#                  NFL Transactions
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/transactions/trade/">
#                  Trade Tracker
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/transactions/signed-free-agent/">
#                  Free Agent Signings
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/transactions/upcoming/">
#                  Future Bonuses &amp; Guarantees
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li>
#              <a href="#">
#               Premium Tools
#              </a>
#              <div class="subnav-posts">
#               <ul class="menu-list" style="width:50%">
#                <li>
#                 <a href="https://www.spotrac.com/nfl/contracts/breakdown/">
#                  Contract Breakdowns by Year
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.spotrac.com/nfl/yearly/">
# ...
#         <td class=" center">
#          $179,872,330
#         </td>
#         <td class="result center">
#          <span style="display:none">
#           1642164
#          </span>
#          $1,642,164
#         </td>
#        </tr>
#        <tr class="parent">
#         <td class="center small">
#          31
#         </td>
#         <td class=" player noborderleft">
#          <a href="https://www.spotrac.com/redirect/team/20/cap/">
#           <span class="xs-hide">
#            Minnesota Vikings
#           </span>
#           <span class="visible-xs">
#            MIN
#           </span>
#          </a>
#         </td>
#         <td class=" center xs-hide">
#          53
#         </td>
#         <td class=" center xs-hide">
#          25.75
#         </td>
#         <td class=" center xs-hide">
#          $172,763,838
#         </td>
#         <td class=" center xs-hide">
#          $7,110,150
#         </td>
#         <td class=" center xs-hide">
#          $13,729,203
#         </td>
#         <td class=" center">
#          $190,331,422
#         </td>
#         <td class="result center">
#          <span style="display:none">
#           597781
#          </span>
#          $597,781
#         </td>
#        </tr>
#        <tr class="parent">
#         <td class="center small">
#          32
#         </td>
#         <td class=" player noborderleft">
#          <a href="https://www.spotrac.com/redirect/team/4/cap/">
#           <span class="xs-hide">
#            Carolina Panthers
#           </span>
#           <span class="visible-xs">
#            CAR
#           </span>
#          </a>
#         </td>
#         <td class=" center xs-hide">
#          53
#         </td>
#         <td class=" center xs-hide">
#          26.7
#         </td>
#         <td class=" center xs-hide">
#          $138,590,418
#         </td>
#         <td class=" center xs-hide">
#          $12,588,681
#         </td>
#         <td class=" center xs-hide">
#          $4,400,316
#         </td>
#         <td class=" center">
#          $184,921,777
#         </td>
#         <td class="result center">
#          <span style="display:none">
#           -3321461
#          </span>
#          $-3,321,461
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </div>
#    <!-- end:main -->
#   </div>
#   <!-- start:sidebar -->
#   <div id="sidebar">
#    <div class="ad">
#     <script>
#      var windowWidth = window.innerWidth
#
# $(document).ready(function(){
#
#     if(windowWidth <= 767)  // load xs
#     {
# 		size = 'xs';
#     }
#     else if(windowWidth >= 768 && windowWidth <= 991) // load sm
#     {
# 		size = 'sm';
#     }
#     else if(windowWidth >= 992 && windowWidth <= 1199) // load md
#     {
# 		size = 'md';
#     }
#     else if(windowWidth >= 1200) // load lg
#     {
# 		size = 'lg';
#     }
#
#
# 	$.ajax({
# 	  type: 'post',
# 	  url: 'https://www.spotrac.com/ads/load300Ad/'+size+'/google/',
# 	  data: 'refer=nfl/cap',
# 	  success: function(data)
# 	  {
# 		  $( "div.ad-wrapper-89730553348" ).html( data );
# 	  }
# 	});
#
# })
#     </script>
#     <div class="ad-wrapper-89730553348">
#     </div>
#    </div>
#    <!-- start:section-module-singles -->
#    <section class="module-singles list">
#     <!-- start:header -->
#     <header>
#      <h2>
#       Trending Players
#       <span class="glyphicon glyphicon-chevron-up">
#       </span>
#      </h2>
#      <span class="borderline">
#      </span>
#     </header>
#     <!-- end:header -->
#     <!-- start:singles-container -->
#     <ul class="singles-container">
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/redirect/player/14924/'">
#       <a class="view" href="https://www.spotrac.com/redirect/player/14924/">
#        view
#       </a>
#       <span class="rank">
#        1
#       </span>
#       <a href="https://www.spotrac.com/redirect/player/14924/">
#        Cody Parkey (K, CHI)
#       </a>
#      </li>
#      <li onclick="window.location.href='https://www.spotrac.com/redirect/player/3115/'">
#       <a class="view" href="https://www.spotrac.com/redirect/player/3115/">
#        view
#       </a>
#       <span class="rank">
#        2
#       </span>
#       <a href="https://www.spotrac.com/redirect/player/3115/">
#        Brandon Mebane (DT, LAC)
#       </a>
#      </li>
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/redirect/player/9898/'">
#       <a class="view" href="https://www.spotrac.com/redirect/player/9898/">
#        view
#       </a>
#       <span class="rank">
#        3
#       </span>
#       <a href="https://www.spotrac.com/redirect/player/9898/">
#        Nick Foles (QB, PHI)
#       </a>
#      </li>
#      <li onclick="window.location.href='https://www.spotrac.com/redirect/player/10079/'">
#       <a class="view" href="https://www.spotrac.com/redirect/player/10079/">
#        view
#       </a>
#       <span class="rank">
#        4
#       </span>
#       <a href="https://www.spotrac.com/redirect/player/10079/">
#        Case Keenum (QB, DEN)
#       </a>
#      </li>
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/redirect/player/4000/'">
#       <a class="view" href="https://www.spotrac.com/redirect/player/4000/">
#        view
#       </a>
#       <span class="rank">
#        5
#       </span>
#       <a href="https://www.spotrac.com/redirect/player/4000/">
#        Joe Flacco (QB, BAL)
#       </a>
#      </li>
#     </ul>
#     <!-- end:singles-container -->
#    </section>
#    <div class="ad">
#     <script type="text/javascript">
#      document.writeln('<ins id="friendly_%%CACHEBUSTER%%">\r\n<scr'+'ipt type="text/javascript" src="https://tradehouse.advertserve.com/servlet/view/banner/javascript/zone?zid=326&friendly=friendly_%%CACHEBUSTER%%&pid=0&fr=400&frlm=1&random=%%CACHEBUSTER%%&encode=1&origin='+encodeURIComponent((window!=top&&window.location.ancestorOrigins)?window.location.ancestorOrigins[window.location.ancestorOrigins.length-1]:document.location)+'&referrer=%%REFERRER_URL_UNESC%%&cturl=%%CLICK_URL_UNESC%%"></scr'+'ipt>\r\n</ins>');
#     </script>
#    </div>
#    <!-- start:section-module-singles -->
#    <section class="module-singles list">
#     <!-- start:header -->
#     <header>
#      <h2>
#       Trending Pages
#       <span class="glyphicon glyphicon-chevron-up">
#       </span>
#      </h2>
#      <span class="borderline">
#      </span>
#     </header>
#     <!-- end:header -->
#     <!-- start:singles-container -->
#     <ul class="singles-container">
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/https://www.spotrac.com/nfl/cap/2019/'">
#       <a class="view" href="https://www.spotrac.com/https://www.spotrac.com/nfl/cap/2019/">
#        view
#       </a>
#       <span class="rank">
#        1
#       </span>
#       <a href="http://www.spotrac.com/nfl/cap/2019/">
#        NFL Cap Tracker
#       </a>
#      </li>
#      <li onclick="window.location.href='https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/'">
#       <a class="view" href="https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/">
#        view
#       </a>
#       <span class="rank">
#        2
#       </span>
#       <a href="http://www.spotrac.com/nfl/free-agents/">
#        2019 NFL Free Agents
#       </a>
#      </li>
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/https://www.spotrac.com/nfl/'">
#       <a class="view" href="https://www.spotrac.com/https://www.spotrac.com/nfl/">
#        view
#       </a>
#       <span class="rank">
#        3
#       </span>
#       <a href="http://www.spotrac.com/nfl/">
#        NFL Homepage
#       </a>
#      </li>
#      <li onclick="window.location.href='https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/all/wide-receiver/'">
#       <a class="view" href="https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/all/wide-receiver/">
#        view
#       </a>
#       <span class="rank">
#        4
#       </span>
#       <a href="http://www.spotrac.com/nfl/free-agents/all/wide-receiver/">
#        2019 NFL Free Agents - Wide Receiver
#       </a>
#      </li>
#      <li class="odd" onclick="window.location.href='https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/offensive-line/'">
#       <a class="view" href="https://www.spotrac.com/https://www.spotrac.com/nfl/free-agents/offensive-line/">
#        view
#       </a>
#       <span class="rank">
#        5
#       </span>
#       <a href="http://www.spotrac.com/nfl/free-agents/offensive-line/">
#        2019 NFL Free Agents - Offensive Line
#       </a>
#      </li>
#     </ul>
#     <!-- end:singles-container -->
#    </section>
#    <div class="ad">
#     <script>
#      var windowWidth = window.innerWidth
#
# $(document).ready(function(){
#
#     if(windowWidth <= 767)  // load xs
#     {
# 		size = 'xs';
#     }
#     else if(windowWidth >= 768 && windowWidth <= 991) // load sm
#     {
# 		size = 'sm';
#     }
#     else if(windowWidth >= 992 && windowWidth <= 1199) // load md
#     {
# 		size = 'md';
#     }
#     else if(windowWidth >= 1200) // load lg
#     {
# 		size = 'lg';
#     }
#
#
# 	$.ajax({
# 	  type: 'post',
# 	  url: 'https://www.spotrac.com/ads/load300Ad/'+size+'/googletag/',
# 	  data: 'refer=nfl/cap',
# 	  success: function(data)
# 	  {
# 		  $( "div.ad-wrapper-66524375758" ).html( data );
# 	  }
# 	});
#
# })
#     </script>
#     <div class="ad-wrapper-66524375758">
#     </div>
#    </div>
#   </div>
#   <!-- end:sidebar -->
#  </div>
#  <!-- end:page content -->
# </div>
# <!-- end:container -->
# <!-- footer:page footer -->
# <footer id="page-footer">
#  <!-- start:container -->
#  <div class="container xlarge">
#   <nav class="hidden-xs" id="foot-menu">
#    <ul class="clearfix">
#     <li class="home current">
#      <a href="#">
#       <span class="glyphicon glyphicon-home">
#       </span>
#      </a>
#     </li>
#     <li class="cat-nfl">
#      <a href="https://www.spotrac.com/nfl/">
#       NFL
#      </a>
#     </li>
#     <li class="cat-nba">
#      <a href="https://www.spotrac.com/nba/">
#       NBA
#      </a>
#     </li>
#     <li class="cat-mlb">
#      <a href="https://www.spotrac.com/mlb/">
#       MLB
#      </a>
#     </li>
#     <li class="cat-nhl">
#      <a href="https://www.spotrac.com/nhl/">
#       NHL
#      </a>
#     </li>
#     <li class="cat-mls">
#      <a href="https://www.spotrac.com/mls/">
#       MLS
#      </a>
#     </li>
#     <li class="cat-epl">
#      <a href="https://www.spotrac.com/epl/">
#       EPL
#      </a>
#     </li>
#     <li class="cat-extra">
#      <a href="https://www.spotrac.com/research/">
#       Research
#      </a>
#     </li>
#     <li class="cat-extra">
#      <a href="https://www.spotrac.com/blog/" target="_blank">
#       Blog
#      </a>
#     </li>
#     <li class="options">
#      <a class="scrollToTop" href="#">
#       Back to top
#       <span class="glyphicon glyphicon-chevron-up">
#       </span>
#      </a>
#     </li>
#    </ul>
#   </nav>
#   <!-- start:row -->
#   <div class="about row">
#    <!-- start:col -->
#    <div class="col-sm-12 col-md-3 xs-hide">
#     <h3>
#      <a href="https://www.spotrac.com/">
#       <img alt="Spotrac" src="https://www.spotrac.com/resources/images/logo-black.png"/>
#      </a>
#     </h3>
#    </div>
#    <!-- end:col -->
#    <!-- start:col -->
#    <div class="col-sm-6 col-md-5">
#     <h4>
#      About Spotrac
#     </h4>
#     <p>
#      Browse our online application for MLB, NBA, NFL, NHL, EPL, or MLS player contracts, salaries, transactions, and more.
#     </p>
#     <a href="https://www.twitter.com/spotrac" target="_blank">
#      <i class="fa fa-twitter fa-lg">
#      </i>
#     </a>
#     <a href="https://www.facebook.com/spotrac" target="_blank">
#      <i class="fa fa-facebook-square fa-lg">
#      </i>
#     </a>
#    </div>
#    <!-- end:col -->
#    <!-- start:col -->
#    <div class="col-sm-6 col-md-4">
#     <h4>
#      Additional information
#     </h4>
#     <ul>
#      <li>
#       <a href="https://www.spotrac.com/about/">
#        About Spotrac
#       </a>
#      </li>
#      <li>
#       <a href="https://www.spotrac.com/media/">
#        Media Requests
#       </a>
#      </li>
#      <li>
#       <a href="https://www.spotrac.com/advertise/">
#        Advertise with Us
#       </a>
#      </li>
#      <li>
#       <a href="https://www.spotrac.com/privacy/">
#        Privacy Policy
#       </a>
#      </li>
#      <li>
#       <a href="https://policies.google.com/technologies/partner-sites" target="_blank">
#        Google Privacy
#       </a>
#      </li>
#      <li>
#       <a href="https://www.spotrac.com/contact/">
#        Contact Us
#       </a>
#      </li>
#      <li>
#       <a href="https://www.spotrac.com/sources-affiliates/">
#        Sources &amp; Affiliates
#       </a>
#      </li>
#     </ul>
#    </div>
#    <!-- end:col -->
#   </div>
#   <!-- end:row -->
#   <!-- start:row -->
#   <div class="copyright row">
#    <!-- start:col -->
#    <div class="col-sm-6">
#     ©
#     <a href="https://www.spotrac.com/">
#      Spotrac
#     </a>
#     2019. All rights reserved.
#    </div>
#    <!-- end:col -->
#    <!-- start:col -->
#    <div class="col-sm-6 text-right">
#     Partnered with the USA TODAY Sports Media Group  |  Powered by
#     <a href="https://mg3webworks.com">
#      MG3 WebWorks
#     </a>
#     .
#    </div>
#    <!-- end:col -->
#   </div>
#   <!-- end:row -->
#  </div>
#  <!-- end:container -->
# </footer>
# <!-- end:page footer -->
# <script>
#  function openCity(evt, cityName) {
#     var i, tabcontent, tablinks;
#     tabcontent = document.getElementsByClassName("tabcontent");
#     for (i = 0; i < tabcontent.length; i++) {
#         tabcontent[i].style.display = "none";
#     }
#     tablinks = document.getElementsByClassName("tablinks");
#     for (i = 0; i < tablinks.length; i++) {
#         tablinks[i].className = tablinks[i].className.replace(" active", "");
#     }
#     document.getElementById(cityName).style.display = "block";
#     evt.currentTarget.className += " active";
# }
#
# // Get the element with id="defaultOpen" and click on it
# document.getElementById("defaultOpen").click();
# </script>
# <script>
#  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-4232275-1', 'auto');
#   ga('require', 'linkid', 'linkid.js');
#   ga('send', 'pageview');
# </script>
# <script src="https://www.spotrac.com/resources/js/ga_social_tracking.js">
# </script>
# <script>
#  _ga.trackTwitter();
#   _ga.trackFacebook();//Google Analytics tracking
# </script>
# <!-- Default Statcounter code for Spotrac https://www.spotrac.com -->
# <script type="text/javascript">
#  var sc_project=11875557;
# var sc_invisible=1;
# var sc_security="7ab33fbd";
# var sc_https=1;
# </script>
# <script async="" src="https://www.statcounter.com/counter/counter.js" type="text/javascript">
# </script>
# <noscript>
#  <div class="statcounter">
#   <a href="http://statcounter.com/" target="_blank" title="website statistics">
#    <img alt="website
# statistics" class="statcounter" src="//c.statcounter.com/11875557/0/7ab33fbd/1/"/>
#   </a>
#  </div>
# </noscript>
# <!-- End of Statcounter Code -->
# <!-- end:page inner wrap -->
# <!-- end:page outer wrap -->
# <!-- start:scripts -->
# <script src="https://www.spotrac.com/resources/js/bootstrap.min.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/jquery.sidr.min.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/jquery.carouFredSel-6.2.1-packed.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/jquery.touchSwipe.min.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/functions.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/jquery.tablesorter.min.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/jquery.tablesorter.widgets.js">
# </script>
# <script src="https://www.spotrac.com/resources/js/site.js">
# </script>
# <script>
#  $("table th").click(function(){
#
# 			$("tr.average td.average div").hide();
#
# 			console.log("#average"+$(this).attr("id")+"2")
#
# 			$("#average"+$(this).attr("id")).find("div").show();
# 			$("#average"+$(this).attr("id")+"2").show();
# 		});
#
# 		$("table.captracker").bind("sortStart",function() {
#
# 		}).bind("sortEnd",function() {
#
# 			col = $("th:not(.tablesorter-headerUnSorted").index();
#
# 			$("table.captracker tbody tr td").removeClass("result");
#
# 			$("table.captracker tbody tr:not(.average)").each(function(i){
# 				 $(this).find("td:eq("+col+")").addClass("result");
# 			});
# 		});
# </script>
# <!-- end:scripts -->

# %%
test = soup.find_all('span', class_="xs-hide")
print(test)
# Out:
# [<span class="label xs-hide">Viewing:</span>, <span class="xs-hide">Cleveland Browns</span>, <span class="xs-hide">Indianapolis Colts</span>, <span class="xs-hide">San Francisco 49ers</span>, <span class="xs-hide">Tennessee Titans</span>, <span class="xs-hide">Pittsburgh Steelers</span>, <span class="xs-hide">New York Jets</span>, <span class="xs-hide">Houston Texans</span>, <span class="xs-hide">Baltimore Ravens</span>, <span class="xs-hide">Buffalo Bills</span>, <span class="xs-hide">Dallas Cowboys</span>, <span class="xs-hide">Cincinnati Bengals</span>, <span class="xs-hide">Miami Dolphins</span>, <span class="xs-hide">New York Giants</span>, <span class="xs-hide">Jacksonville Jaguars</span>, <span class="xs-hide">Philadelphia Eagles</span>, <span class="xs-hide">Oakland Raiders</span>, <span class="xs-hide">Washington Redskins</span>, <span class="xs-hide">Detroit Lions</span>, <span class="xs-hide">Denver Broncos</span>, <span class="xs-hide">Green Bay Packers</span>, <span class="xs-hide">Chicago Bears</span>, <span class="xs-hide">Arizona Cardinals</span>, <span class="xs-hide">Atlanta Falcons</span>, <span class="xs-hide">New England Patriots</span>, <span class="xs-hide">Kansas City Chiefs</span>, <span class="xs-hide">Seattle Seahawks</span>, <span class="xs-hide">Los Angeles Chargers</span>, <span class="xs-hide">Tampa Bay Buccaneers</span>, <span class="xs-hide">New Orleans Saints</span>, <span class="xs-hide">Los Angeles Rams</span>, <span class="xs-hide">Minnesota Vikings</span>, <span class="xs-hide">Carolina Panthers</span>]

# %%
teams = []
for x in test:
    name = str(x)
    name = substring.substringByChar(name, startChar='>', endChar='<')
    if name.startswith('>') and name.endswith('<'):
        name = name[1:-1]
    if ":" not in name:
        teams.append(name)
teams
# Out:
# ['Cleveland Browns',
#  'Indianapolis Colts',
#  'San Francisco 49ers',
#  'Tennessee Titans',
#  'Pittsburgh Steelers',
#  'New York Jets',
#  'Houston Texans',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Cincinnati Bengals',
#  'Miami Dolphins',
#  'New York Giants',
#  'Jacksonville Jaguars',
#  'Philadelphia Eagles',
#  'Oakland Raiders',
#  'Washington Redskins',
#  'Detroit Lions',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Chicago Bears',
#  'Arizona Cardinals',
#  'Atlanta Falcons',
#  'New England Patriots',
#  'Kansas City Chiefs',
#  'Seattle Seahawks',
#  'Los Angeles Chargers',
#  'Tampa Bay Buccaneers',
#  'New Orleans Saints',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'Carolina Panthers']

# %%
nfl_data = pd.DataFrame(columns=("Active Players", "Pos", "Base Salary", "Signing Bonus", "Roster Bonus", "Option Bonus", "Workout Bonus", "Restruc Bonus", "Misc", "Dead Cap", "Cap Hit", "Cap %"))
def scraper(team_name):
    formatted = team_name.lower()
    formatted = formatted.replace(" ", "-")
    url = "https://www.spotrac.com/nfl/" + formatted + "/cap"

# %%
url = "https://www.spotrac.com/nfl/cleveland-browns/cap/"
team = "Cleveland Browns"
table = pd.read_html(url, match = "Active Players")
team_table = table[0]
team_table.rename(index=str, columns={"Pos.":"Pos", "Restruc. Bonus":"Restruc Bonus", "Misc.":"Misc"}, inplace=True)
team_table.rename(index=str, columns={team_table.iloc[:,0].name:"Active Players"}, inplace=True)
team_table["Team"] = team

# %%
nfl_data = pd.concat([nfl_data, team_table])
nfl_data
# Out:
# C:\Users\jgran\Anaconda3\envs\pythondata\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
#            Active Players  Base Salary  Cap %      Cap Hit       Dead Cap  \
# 0            Tyrod Taylor  $10,000,000   6.78  $16,000,000  ($16,000,000)
# 1           Jarvis Landry   $3,500,000   6.56  $15,500,000  ($34,000,000)
# 2           Jamie Collins  $10,650,000   5.25  $12,400,000  ($14,500,000)
# 3           Kevin Zeitler  $10,000,000   5.25  $12,400,000  ($23,100,000)
# 4           Myles Garrett   $1,847,375   2.93   $6,911,876  ($24,882,754)
# 5            J.C. Tretter   $5,000,000   2.86   $6,750,000   ($8,000,000)
# 6            Joel Bitonio   $5,500,000   2.54   $6,000,000   ($6,835,223)
# 7          Baker Mayfield     $480,000   2.52   $5,942,360  ($32,682,980)
# 8           Chris Hubbard   $2,500,000   2.46   $5,800,000   ($9,000,000)
# 9             Denzel Ward     $480,000   2.25   $5,302,792  ($29,165,356)
# 10          Travis Carrie   $2,000,000   2.24   $5,300,000   ($5,600,000)
# 11           Duke Johnson     $957,000   1.65   $3,894,523   ($6,144,523)
# 12           Darren Fells   $1,150,000   1.52   $3,600,000   ($4,750,000)
# 13            Chris Smith   $1,000,000   1.13   $2,666,666   ($4,600,000)
# 14       Britton Colquitt   $2,550,000   1.08   $2,550,000   ($2,550,000)
# 15      Terrance Mitchell   $1,500,000   1.04   $2,466,666   ($3,600,000)
# 16        Jabrill Peppers     $935,090   1.00   $2,350,451   ($6,586,356)
# 17           Drew Stanton   $1,150,000   0.96   $2,265,625   ($4,250,000)
# 18            David Njoku     $897,959   0.92   $2,164,794   ($7,793,261)
# 19         Emmanuel Ogbah   $1,050,876   0.76   $1,802,629   ($2,103,506)
# 20      Damarious Randall   $1,090,381   0.64   $1,514,418              -
# 21          Austin Corbet     $480,000   0.58   $1,376,000   ($5,234,718)
# 22             Nick Chubb     $480,000   0.57   $1,342,381   ($5,896,309)
# 23           Earl Watford     $950,000   0.40     $950,000     ($790,000)
# 24         Larry Ogunjobi     $642,500   0.38     $887,891     ($736,173)
# 25          Greg Robinson     $790,000   0.33     $790,000     ($790,000)
# 26           Joe Schobert     $630,000   0.33     $788,489     ($316,978)
# 27        Derrick Kindred     $630,000   0.32     $754,839     ($249,678)
# 28            Chad Thomas     $480,000   0.31     $742,235   ($1,048,940)
# 29           Seth Devalve     $630,000   0.31     $725,848     ($191,697)
# 30             Carl Davis     $720,750   0.31     $720,750              -
# 31       Charley Hughlett     $705,000   0.30     $705,000              -
# 32       Antonio Callaway     $480,000   0.28     $659,463     ($717,853)
# 33   Briean Boddy-Calhoun     $630,000   0.27     $630,000              -
# 34        Rashard Higgins     $630,000   0.27     $630,000              -
# 35         Anthony Zettel     $630,000   0.27     $630,000              -
# 36      Ray-Ray Armstrong     $588,235   0.25     $588,235              -
# 37           Trevon Coley     $555,000   0.24     $555,000              -
# 38           Genard Avery     $480,000   0.23     $552,236     ($288,947)
# 39          Damion Ratley     $480,000   0.22     $528,466     ($193,866)
# 40            Brian Price     $518,812   0.22     $518,812              -
# 41       Breshad Perriman     $497,647   0.21     $497,647              -
# 42       Desmond Harrison     $480,000   0.21     $486,666      ($20,000)
# 43        Tavierre Thomas     $480,000   0.20     $480,000              -
# 44           D’Juan Hines     $423,529   0.18     $423,529              -
# 45            Greg Joseph     $423,529   0.18     $423,529              -
# 46      Dontrell Hilliard     $338,820   0.14     $338,820              -
# 47         Phillip Gaines     $296,471   0.13     $296,471     ($790,000)
# 48          Juston Burris     $296,471   0.13     $296,470              -
# 49     Jermaine Whitehead     $261,176   0.11     $261,176              -
# 50             Kyle Kalis     $163,235   0.07     $163,235              -
# 51  Xavier Woodson-Luster      $97,941   0.04      $97,941              -
# 52          Blake Jackson      $28,235   0.01      $28,235              -
#
#    Misc Option Bonus  Pos Restruc Bonus Roster Bonus Signing Bonus  \
# 0     -            -   QB             -   $6,000,000             -
# 1     -            -   WR             -  $10,500,000    $1,500,000
# 2     -            -  OLB             -     $400,000    $1,250,000
# 3     -            -    G             -            -    $2,400,000
# 4     -            -   DE             -            -    $5,064,501
# 5     -            -    C             -     $250,000    $1,500,000
# 6     -            -    G             -     $500,000             -
# 7     -            -   QB             -            -    $5,462,360
# 8     -            -   RT             -   $2,500,000      $800,000
# 9     -            -   CB             -            -    $4,822,792
# 10    -            -   CB             -   $2,400,000      $900,000
# 11    -            -   RB             -   $2,000,000      $927,523
# 12    -            -   TE             -   $1,650,000      $700,000
# 13    -            -   DE             -     $400,000    $1,166,666
# 14    -            -    P             -            -             -
# 15    -            -   CB             -     $200,000      $666,666
# 16    -            -   SS             -            -    $1,415,361
# 17    -            -   QB             -      $15,625    $1,000,000
# 18    -            -   TE             -            -    $1,266,835
# 19    -            -   DE             -            -      $751,753
# 20    -            -   FS             -     $424,037             -
# 21    -            -    G             -            -      $896,000
# 22    -            -   RB             -            -      $862,381
# 23    -            -   RT             -            -             -
# 24    -            -   DT             -            -      $245,391
# 25    -            -   LT             -            -             -
# 26    -            -  ILB             -            -      $158,489
# 27    -            -    S             -            -      $124,839
# 28    -            -   DE             -            -      $262,235
# 29    -            -   TE             -            -       $95,848
# 30    -            -   DT             -            -             -
# 31    -            -   LS             -            -             -
# 32    -            -   WR             -            -      $179,463
# 33    -            -   CB             -            -             -
# 34    -            -   WR             -            -             -
# 35    -            -   DE             -            -             -
# 36    -            -  OLB             -            -             -
# 37    -            -   DT             -            -             -
# 38    -            -  ILB             -            -       $72,236
# 39    -            -   WR             -            -       $48,466
# 40    -            -   DT             -            -             -
# 41    -            -   WR             -            -             -
# 42    -            -   LT             -            -        $6,666
# 43    -            -    S             -            -             -
# 44    -            -   LB             -            -             -
# 45    -            -    K             -            -             -
# 46    -            -   RB             -            -             -
# 47    -            -   CB             -            -             -
# 48    -            -   CB             -            -             -
# 49    -            -   FS             -            -             -
# 50    -            -    T             -            -             -
# 51    -            -  ILB             -            -             -
# 52    -            -   WR             -            -             -
#
#                 Team Workout Bonus
# 0   Cleveland Browns             -
# 1   Cleveland Browns             -
# 2   Cleveland Browns      $100,000
# 3   Cleveland Browns             -
# 4   Cleveland Browns             -
# 5   Cleveland Browns             -
# 6   Cleveland Browns             -
# 7   Cleveland Browns             -
# 8   Cleveland Browns             -
# 9   Cleveland Browns             -
# 10  Cleveland Browns             -
# 11  Cleveland Browns       $10,000
# 12  Cleveland Browns      $100,000
# 13  Cleveland Browns      $100,000
# 14  Cleveland Browns             -
# 15  Cleveland Browns      $100,000
# 16  Cleveland Browns             -
# 17  Cleveland Browns      $100,000
# 18  Cleveland Browns             -
# 19  Cleveland Browns             -
# 20  Cleveland Browns             -
# 21  Cleveland Browns             -
# 22  Cleveland Browns             -
# 23  Cleveland Browns             -
# 24  Cleveland Browns             -
# 25  Cleveland Browns             -
# 26  Cleveland Browns             -
# 27  Cleveland Browns             -
# 28  Cleveland Browns             -
# 29  Cleveland Browns             -
# 30  Cleveland Browns             -
# 31  Cleveland Browns             -
# 32  Cleveland Browns             -
# 33  Cleveland Browns             -
# 34  Cleveland Browns             -
# 35  Cleveland Browns             -
# 36  Cleveland Browns             -
# 37  Cleveland Browns             -
# 38  Cleveland Browns             -
# 39  Cleveland Browns             -
# 40  Cleveland Browns             -
# 41  Cleveland Browns             -
# 42  Cleveland Browns             -
# 43  Cleveland Browns             -
# 44  Cleveland Browns             -
# 45  Cleveland Browns             -
# 46  Cleveland Browns             -
# 47  Cleveland Browns             -
# 48  Cleveland Browns             -
# 49  Cleveland Browns             -
# 50  Cleveland Browns             -
# 51  Cleveland Browns             -
# 52  Cleveland Browns             -

# %%
position_map = pd.read_csv("positions.csv")
new_main = main.merge(position_map, on = "Pos")
new_main
# Out:
#       Active Players (53)  Pos  Base Salary Signing Bonus Roster Bonus  \
# 0            Tyrod Taylor   QB  $10,000,000             -   $6,000,000
# 1          Baker Mayfield   QB     $480,000    $5,462,360            -
# 2            Drew Stanton   QB   $1,150,000    $1,000,000      $15,625
# 3           Jarvis Landry   WR   $3,500,000    $1,500,000  $10,500,000
# 4        Antonio Callaway   WR     $480,000      $179,463            -
# 5         Rashard Higgins   WR     $630,000             -            -
# 6           Damion Ratley   WR     $480,000       $48,466            -
# 7        Breshad Perriman   WR     $497,647             -            -
# 8           Blake Jackson   WR      $28,235             -            -
# 9           Jamie Collins  OLB  $10,650,000    $1,250,000     $400,000
# 10      Ray-Ray Armstrong  OLB     $588,235             -            -
# 11          Kevin Zeitler    G  $10,000,000    $2,400,000            -
# 12           Joel Bitonio    G   $5,500,000             -     $500,000
# 13          Austin Corbet    G     $480,000      $896,000            -
# 14          Myles Garrett   DE   $1,847,375    $5,064,501            -
# 15            Chris Smith   DE   $1,000,000    $1,166,666     $400,000
# 16         Emmanuel Ogbah   DE   $1,050,876      $751,753            -
# 17            Chad Thomas   DE     $480,000      $262,235            -
# 18         Anthony Zettel   DE     $630,000             -            -
# 19           J.C. Tretter    C   $5,000,000    $1,500,000     $250,000
# 20          Chris Hubbard   RT   $2,500,000      $800,000   $2,500,000
# 21           Earl Watford   RT     $950,000             -            -
# 22            Denzel Ward   CB     $480,000    $4,822,792            -
# 23          Travis Carrie   CB   $2,000,000      $900,000   $2,400,000
# 24      Terrance Mitchell   CB   $1,500,000      $666,666     $200,000
# 25   Briean Boddy-Calhoun   CB     $630,000             -            -
# 26         Phillip Gaines   CB     $296,471             -            -
# 27          Juston Burris   CB     $296,471             -            -
# 28           Duke Johnson   RB     $957,000      $927,523   $2,000,000
# 29             Nick Chubb   RB     $480,000      $862,381            -
# 30      Dontrell Hilliard   RB     $338,820             -            -
# 31           Darren Fells   TE   $1,150,000      $700,000   $1,650,000
# 32            David Njoku   TE     $897,959    $1,266,835            -
# 33           Seth Devalve   TE     $630,000       $95,848            -
# 34       Britton Colquitt    P   $2,550,000             -            -
# 35        Jabrill Peppers   SS     $935,090    $1,415,361            -
# 36      Damarious Randall   FS   $1,090,381             -     $424,037
# 37     Jermaine Whitehead   FS     $261,176             -            -
# 38         Larry Ogunjobi   DT     $642,500      $245,391            -
# 39             Carl Davis   DT     $720,750             -            -
# 40           Trevon Coley   DT     $555,000             -            -
# 41            Brian Price   DT     $518,812             -            -
# 42          Greg Robinson   LT     $790,000             -            -
# 43       Desmond Harrison   LT     $480,000        $6,666            -
# 44           Joe Schobert  ILB     $630,000      $158,489            -
# 45           Genard Avery  ILB     $480,000       $72,236            -
# 46  Xavier Woodson-Luster  ILB      $97,941             -            -
# 47        Derrick Kindred    S     $630,000      $124,839            -
# 48        Tavierre Thomas    S     $480,000             -            -
# 49       Charley Hughlett   LS     $705,000             -            -
# 50           D’Juan Hines   LB     $423,529             -            -
# 51            Greg Joseph    K     $423,529             -            -
# 52             Kyle Kalis    T     $163,235             -            -
#
#    Option Bonus Workout Bonus Restruc Bonus Misc       Dead Cap      Cap Hit  \
# 0             -             -             -    -  ($16,000,000)  $16,000,000
# 1             -             -             -    -  ($32,682,980)   $5,942,360
# 2             -      $100,000             -    -   ($4,250,000)   $2,265,625
# 3             -             -             -    -  ($34,000,000)  $15,500,000
# 4             -             -             -    -     ($717,853)     $659,463
# 5             -             -             -    -              -     $630,000
# 6             -             -             -    -     ($193,866)     $528,466
# 7             -             -             -    -              -     $497,647
# 8             -             -             -    -              -      $28,235
# 9             -      $100,000             -    -  ($14,500,000)  $12,400,000
# 10            -             -             -    -              -     $588,235
# 11            -             -             -    -  ($23,100,000)  $12,400,000
# 12            -             -             -    -   ($6,835,223)   $6,000,000
# 13            -             -             -    -   ($5,234,718)   $1,376,000
# 14            -             -             -    -  ($24,882,754)   $6,911,876
# 15            -      $100,000             -    -   ($4,600,000)   $2,666,666
# 16            -             -             -    -   ($2,103,506)   $1,802,629
# 17            -             -             -    -   ($1,048,940)     $742,235
# 18            -             -             -    -              -     $630,000
# 19            -             -             -    -   ($8,000,000)   $6,750,000
# 20            -             -             -    -   ($9,000,000)   $5,800,000
# 21            -             -             -    -     ($790,000)     $950,000
# 22            -             -             -    -  ($29,165,356)   $5,302,792
# 23            -             -             -    -   ($5,600,000)   $5,300,000
# 24            -      $100,000             -    -   ($3,600,000)   $2,466,666
# 25            -             -             -    -              -     $630,000
# 26            -             -             -    -     ($790,000)     $296,471
# 27            -             -             -    -              -     $296,470
# 28            -       $10,000             -    -   ($6,144,523)   $3,894,523
# 29            -             -             -    -   ($5,896,309)   $1,342,381
# 30            -             -             -    -              -     $338,820
# 31            -      $100,000             -    -   ($4,750,000)   $3,600,000
# 32            -             -             -    -   ($7,793,261)   $2,164,794
# 33            -             -             -    -     ($191,697)     $725,848
# 34            -             -             -    -   ($2,550,000)   $2,550,000
# 35            -             -             -    -   ($6,586,356)   $2,350,451
# 36            -             -             -    -              -   $1,514,418
# 37            -             -             -    -              -     $261,176
# 38            -             -             -    -     ($736,173)     $887,891
# 39            -             -             -    -              -     $720,750
# 40            -             -             -    -              -     $555,000
# 41            -             -             -    -              -     $518,812
# 42            -             -             -    -     ($790,000)     $790,000
# 43            -             -             -    -      ($20,000)     $486,666
# 44            -             -             -    -     ($316,978)     $788,489
# 45            -             -             -    -     ($288,947)     $552,236
# 46            -             -             -    -              -      $97,941
# 47            -             -             -    -     ($249,678)     $754,839
# 48            -             -             -    -              -     $480,000
# 49            -             -             -    -              -     $705,000
# 50            -             -             -    -              -     $423,529
# 51            -             -             -    -              -     $423,529
# 52            -             -             -    -              -     $163,235
#
#     Cap %       Pos Side    Pos Category
# 0    6.78        Offense         Passing
# 1    2.52        Offense         Passing
# 2    0.96        Offense         Passing
# 3    6.56        Offense         Passing
# 4    0.28        Offense         Passing
# 5    0.27        Offense         Passing
# 6    0.22        Offense         Passing
# 7    0.21        Offense         Passing
# 8    0.01        Offense         Passing
# 9    5.25        Defense      Linebacker
# 10   0.25        Defense      Linebacker
# 11   5.25        Offense  Offensive Line
# 12   2.54        Offense  Offensive Line
# 13   0.58        Offense  Offensive Line
# 14   2.93        Defense  Defensive Line
# 15   1.13        Defense  Defensive Line
# 16   0.76        Defense  Defensive Line
# 17   0.31        Defense  Defensive Line
# 18   0.27        Defense  Defensive Line
# 19   2.86        Offense  Offensive Line
# 20   2.46        Offense  Offensive Line
# 21   0.40        Offense  Offensive Line
# 22   2.25        Defense       Secondary
# 23   2.24        Defense       Secondary
# 24   1.04        Defense       Secondary
# 25   0.27        Defense       Secondary
# 26   0.13        Defense       Secondary
# 27   0.13        Defense       Secondary
# 28   1.65        Offense         Rushing
# 29   0.57        Offense         Rushing
# 30   0.14        Offense         Rushing
# 31   1.52        Offense         Passing
# 32   0.92        Offense         Passing
# 33   0.31        Offense         Passing
# 34   1.08  Special Teams   Special Teams
# 35   1.00        Defense       Secondary
# 36   0.64        Defense       Secondary
# 37   0.11        Defense       Secondary
# 38   0.38        Defense  Defensive Line
# 39   0.31        Defense  Defensive Line
# 40   0.24        Defense  Defensive Line
# 41   0.22        Defense  Defensive Line
# 42   0.33        Offense  Offensive Line
# 43   0.21        Offense  Offensive Line
# 44   0.33        Defense      Linebacker
# 45   0.23        Defense      Linebacker
# 46   0.04        Defense      Linebacker
# 47   0.32        Defense       Secondary
# 48   0.20        Defense       Secondary
# 49   0.30  Special Teams   Special Teams
# 50   0.18        Defense      Linebacker
# 51   0.18  Special Teams   Special Teams
# 52   0.07        Offense  Offensive Line

# %%
db.collection.insert_many(new_main.to_dict("records"))
